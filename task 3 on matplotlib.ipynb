# %%
## 1. Monthly Revenue Line Chart
Using order_date and revenue:
• Convert order_date to datetime.
• Calculate total revenue for each month.
• Create a line chart.
• Add:
o Title
o X-axis label
o Y-axis label
o Grid
o Markers

Commands/concepts: plt.plot(), plt.title(), plt.xlabel(), plt.ylabel(), plt.grid()
# Out:
#   Cell In[2], line 3
#     • Convert order_date to datetime.
#     ^
# SyntaxError: invalid character '•' (U+2022)

# %%
import matplotlib.pyplot as plt
import pandas as pd


df=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\cleaned_data_matplotlib_messy_sales.xls")
df.head(2)
# Out:
#   customer_id  order_date    city product_category customer_segment  gender  \
# 0   CUST00594  2025-05-05  Mumbai         Clothing          premium    Male
# 1   CUST01103  2025-10-22  Mumbai         Clothing          premium  Female
#
#   sales_channel   age  units_sold  unit_price  discount_%  customer_rating  \
# 0        Retail  36.0         8.0    24235.73       22.91              1.9
# 1     Corporate  38.0         5.0    16789.55       10.59              4.3
#
#    is_active  returned payment_method  gross_sales  discount_amount  \
# 0          1         0            UPI    193885.84         44419.25
# 1          1         0           Cash     83947.75          8890.07
#
#      revenue      cost    profit
# 0  149466.59  88698.45  60768.14
# 1   75057.68  61426.31  13631.37

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
monthly_revenue = df.groupby(
    df['order_date'].dt.to_period('M')
)['revenue'].sum()
plt.plot(monthly_revenue.index.astype(str),
         monthly_revenue.values,
         marker='o')

plt.title('Monthly Revenue')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.grid(True)
plt.show()

# %%
## 2. Monthly Profit Line Chart
Create a line chart showing monthly Profit.
Requirements:
• Use a different line style.
• Add markers.
• Add a legend.
• Display the value of the highest-profit month using annotate().
Commands/concepts: plt.plot(), plt.legend(), plt.annotate()

# %%
df.head(1)
# Out:
#   customer_id order_date    city product_category customer_segment gender  \
# 0   CUST00594 2025-05-05  Mumbai         Clothing          premium   Male
#
#   sales_channel   age  units_sold  unit_price  discount_%  customer_rating  \
# 0        Retail  36.0         8.0    24235.73       22.91              1.9
#
#    is_active  returned payment_method  gross_sales  discount_amount  \
# 0          1         0            UPI    193885.84         44419.25
#
#      revenue      cost    profit
# 0  149466.59  88698.45  60768.14

# %%
plt.plot(df['order_date'],df['profit'],
         linestyle="--",
         marker="o",
         
        )
plt.xlabel("month")
plt.ylabel("profit")
plt.title("Monthly Profit")

plt.legend(['abc plot'])


plt.show()

# %%
## 3. Revenue by Product Category — Bar Chart
Calculate total revenue for each product_category.
Create a bar chart.
Requirements:
• X-axis → Product Category

Sumit Sir Notes
• Y-axis → Revenue
• Add title and labels.
• Display the revenue value above each bar.
Commands/concepts: plt.bar(), plt.text()

# %%
data = df.groupby("product_category")["revenue"].sum()

# Bar chart
plt.bar(data.index, data.values)

plt.xlabel("Product Category")
plt.ylabel("Revenue")
plt.title("Revenue by Product Category")
plt.show()

# %%
## 4. Profit by City — Horizontal Bar Chart
Calculate total profit for each city.
Create a horizontal bar chart.
Requirements:
• Sort cities by profit.
• Show the highest-profit city first.
• Add title and axis labels.
Commands/concepts: plt.barh(), sort_values()

# %%
data = df.groupby("city")["profit"].sum()

# Sort by profit
data = data.sort_values()
plt.barh(data.index, data.values)

plt.xlabel("Profit")
plt.ylabel("City")
plt.title("Profit by City")

plt.show()

# %%
## 5. Customer Age Histogram
Create a histogram of the age column.
Requirements:
• Use 10 bins.
• Add title.
• Add X/Y labels.
• Add grid.
• Add a vertical line showing the median age.
Commands/concepts: plt.hist(), plt.axvline()z
