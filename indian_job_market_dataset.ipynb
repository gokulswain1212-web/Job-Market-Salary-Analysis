# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\LENOVO\Downloads\indian-job-market-dataset-2025.csv")
df.head()
df.shape
# Out:
# (97929, 17)

# %%
df. columns
# Out:
# Index(['title', 'jobId', 'currency', 'jobUploaded', 'companyName',
#        'tagsAndSkills', 'experience', 'salary', 'location', 'companyId',
#        'ReviewsCount', 'AggregateRating', 'jobDescription', 'minimumSalary',
#        'maximumSalary', 'minimumExperience', 'maximumExperience'],
#       dtype='object')

# %%
df.columns=df.columns.str.title()
df.columns
# Out:
# Index(['Title', 'Jobid', 'Currency', 'Jobuploaded', 'Companyname',
#        'Tagsandskills', 'Experience', 'Salary', 'Location', 'Companyid',
#        'Reviewscount', 'Aggregaterating', 'Jobdescription', 'Minimumsalary',
#        'Maximumsalary', 'Minimumexperience', 'Maximumexperience'],
#       dtype='object')

# %%
df.head(2)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97929 entries, 0 to 97928
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              97929 non-null  object
#  1   Jobid              97929 non-null  int64
#  2   Currency           97929 non-null  object
#  3   Jobuploaded        97929 non-null  object
#  4   Companyname        97925 non-null  object
#  5   Tagsandskills      97358 non-null  object
#  6   Experience         95824 non-null  object
#  7   Salary             97929 non-null  object
#  8   Location           97929 non-null  object
#  9   Companyid          97929 non-null  int64
#  10  Reviewscount       62677 non-null  float64
#  11  Aggregaterating    62677 non-null  float64
#  12  Jobdescription     97929 non-null  object
#  13  Minimumsalary      97358 non-null  float64
#  14  Maximumsalary      97358 non-null  float64
#  15  Minimumexperience  97358 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# Title                    0
# Jobid                    0
# Currency                 0
# Jobuploaded              0
# Companyname              4
# Tagsandskills          571
# Experience            2105
# Salary                   0
# Location                 0
# Companyid                0
# Reviewscount         35252
# Aggregaterating      35252
# Jobdescription           0
# Minimumsalary          571
# Maximumsalary          571
# Minimumexperience      571
# Maximumexperience      571
# dtype: int64

# %%
print(df['Title'].unique())
print("missing value:",df['Title'].isna().sum())
print("_"*40)
print("duplicated:",df['Title'].duplicated().sum())
print("_"*40)
print("check duplicated:",df['Title'].value_counts().head(10))
# Out:
# ['Sr. HR Recruiter (NON IT)' 'Fire And Safety Officer'
#  'Opening For Performance Marketing - Chennai' ...
#  'Sr.Executive/Asst. Manager - Pricing   - Sea Export'
#  'CNC Machine Maintenance Engineer @ Manali, Chennai'
#  'IT Cum Digital Marketing Executive']
# missing value: 0
# ________________________________________
# duplicated: 42825
# ________________________________________
# check duplicated: Title
# Application Developer             2039
# Application Lead                  1347
# Sales Executive                    576
# Software Development Engineer      497
# Business Development Executive     457
# Trust & Safety New Associate       348
# Data Engineer                      339
# Business Development Manager       323
# Sales Manager                      319
# Java Full Stack Developer          283
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           NaN              NaN
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimumsalary  \
# 0                    Preferred candidate profile . .       200000.0
# ...

# %%
# check jobid columns
print("missing value:",df['Jobid'].isna().sum())
print("-"*40)

print("unique:",df['Jobid'].unique())
print("-"*40)

print("duplicate:",df['Jobid'].duplicated().sum())
print("-"*40)

print("count duplicate:",df['Jobid'].value_counts())
# Out:
# missing value: 0
# ----------------------------------------
# unique: [270925008041 270925007584 270925007492 ... 270925008467 270925008099
#  270925008094]
# ----------------------------------------
# duplicate: 250
# ----------------------------------------
# count duplicate: Jobid
# 230925928900    2
# 230925026361    2
# 280925003063    2
# 230925507720    2
# 290925500734    2
#                ..
# 11025024237     1
# 11025024265     1
# 11025500011     1
# 11025500015     1
# 270925008094    1
# Name: count, Length: 97679, dtype: int64

# %%
# check Currency columns
print("missing value:",df['Currency'].isna().sum())
print("-"*50)

print("duplicated:",df['Currency'].duplicated().sum())
print("-"*50)

print("unique value:",df['Currency'].unique())
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 97927
# --------------------------------------------------
# unique value: ['INR' 'USD']

# %%
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           NaN              NaN
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimumsalary  \
# 0                    Preferred candidate profile . .       200000.0
# ...

# %%
# check Jobuploaded columns
print("missing value:",df['Jobuploaded'].isna().sum())
print("-"*50)

print("unique:",df['Jobuploaded'].unique())
print("-"*50)

print("duplicated:",df['Jobuploaded'].duplicated().sum())
print("-"*50)
#df['Jobuploaded']=pd.to_datetime(df['Jobuploaded'],errors="coerce")
#df['Jobuploaded']
# Out:
# missing value: 0
# --------------------------------------------------
# unique: ['6 Days Ago' 'Few Hours Ago' 'Just Now' '3 Days Ago' '4 Days Ago'
#  '1 Day Ago' '2 Days Ago' '7 Days Ago' '5 Days Ago' 'Today' '8 Days Ago'
#  'Starts in 1-3 months' '9 Days Ago' '10 Days Ago' 'Starts within 1 month'
#  "Starts : 6th Oct' 25" "Starts : 3rd Nov' 25" "Starts : 8th Oct' 25"
#  'Starts in 3-6 months' "Starts : 10th Oct' 25" "Starts : 7th Oct' 25"
#  "Starts : 20th Oct' 25" "Starts : 22nd Oct' 25" "Starts : 25th Nov' 25"
#  "Starts : 15th Oct' 25" "Starts : 15th Jan' 26" "Starts : 14th Oct' 25"
#  '15 Days Ago' '20 Days Ago' "Starts : 1st Nov' 25"]
# --------------------------------------------------
# duplicated: 97899
# --------------------------------------------------

# %%
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           NaN              NaN
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimumsalary  \
# 0                    Preferred candidate profile . .       200000.0
# ...

# %%
# check Companyname
print("missing value:",df['Companyname'].isna().sum())
print("*"*40)

# Find most frequent company
company_mode = df["Companyname"].mode()[0]
df['Companyname']=df['Companyname'].fillna(company_mode)
print("fill with mode:",df['Companyname'])

print("*"*40)
print("missing value:",df['Companyname'].isna().sum())
print("*"*40)

# check duplicated
print("duplicated:",df['Companyname'].duplicated().sum())
print("*"*40)
# remove extra space
df['Companyname']=df['Companyname'].str.strip()
df['Companyname']
# Out:
# missing value: 4
# ****************************************
# fill with mode: 0                                                    Orion
# 1        Apollo Hospitals International Limited, Ahmedabad
# 2                                  TVS Credit Services Ltd
# 3                                      GNR Global Services
# 4                                   Cadila Pharmaceuticals
#                                ...
# 97924                                            GSH Group
# 97925                       Luxus Green Mobility Pvt. Ltd.
# 97926                               Cadila Pharmaceuticals
# 97927                                  GNR Global Services
# 97928                               Logon Global Solutions
# Name: Companyname, Length: 97929, dtype: object
# ****************************************
# missing value: 0
# ****************************************
# duplicated: 79261
# ****************************************
# ...

# %%
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           NaN              NaN
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimumsalary  \
# 0                    Preferred candidate profile . .       200000.0
# ...

# %%
# check the Tagsandskills columns
print("missing value:",df['Tagsandskills'].isna().sum())
print("_"*50)
# Out:
# missing value: 571
# __________________________________________________

# %%
#remove missing value using fillna
value=df['Tagsandskills'].mode()[0]
df['Tagsandskills']=df['Tagsandskills'].fillna(value)
print("fill missing value:",df['Tagsandskills'])
print("_"*50)

# after fill check missing value
print("missing value:",df['Tagsandskills'].isna().sum())
print("_"*50)

# check duplicated value
print("duplicated:",df['Tagsandskills'].duplicated().sum())
print("_"*50)
#check how many duplicated have each columns
df['Tagsandskills'].value_counts().head(10)
# Out:
# fill missing value: 0        Communication,Manpower,Staffing,Convincing Pow...
# 1        Safety Officer Activities,Fire Protection,Fire...
# 2        Performance Marketing,User Acquisition,growth ...
# 3        Fluent English,Spoken English,Good English Com...
# 4        Product Marketing,CNS,Product Management,Nephr...
#                                ...
# 97924    CNC Maintenance,CNC Machines,Electrical Mainte...
# 97925    Google AdWords,Digital Marketing,Social Media ...
# 97926    Analytical Method Validation,Analytical Method...
# 97927    Fluent English,Spoken English,Strong Communica...
# 97928    Client Support,English,Client Coordination,Mal...
# Name: Tagsandskills, Length: 97929, dtype: object
# __________________________________________________
# missing value: 0
# __________________________________________________
# duplicated: 13622
# __________________________________________________
# Tagsandskills
# ...

# %%
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           NaN              NaN
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimumsalary  \
# 0                    Preferred candidate profile . .       200000.0
# ...

# %%
# check Experience columns
print("missing value:",df['Experience'].isna().sum())
# Out:
# missing value: 2105

# %%
# fill the missing value using mode
fill=df['Experience'].mode()[0]
# fill missing value
df['Experience']=df['Experience'].fillna(fill)
df['Experience']
print("-"*50)
# check missing value
print("after fill missing value is:",df['Experience'].isna().sum())
print("-"*50)
# check duplicated value
print("duplicated:",df['Experience'].duplicated().sum())
# Out:
# --------------------------------------------------
# after fill missing value is: 0
# --------------------------------------------------
# duplicated: 97642

# %%
#check Salary columns
# check missing value
print("missing value:",df['Salary'].isna().sum())
print("-"*50)

# check  duplicated
print("duplicated:",df['Salary'].duplicated().sum())
print("-"*50)

# check unique value 
print("unique:",df['Salary'].unique())
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 96590
# --------------------------------------------------
# unique: ['2-4 Lacs PA' '3-5 Lacs PA' 'Not disclosed' ... '9-10.08 Lacs PA'
#  '36,000-48,000 PA' '1.92-3.36 Lacs PA']

# %%
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           NaN              NaN
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimumsalary  \
# 0                    Preferred candidate profile . .       200000.0
# ...

# %%
# check Location columns
print("missing value:",df['Location'].isna().sum())
print("*"*50)

# check duplicated
print("duplicated:",df['Location'].duplicated().sum())
print("*"*50)

# check unique value
print("unique:",df['Location'].unique())
# Out:
# missing value: 0
# **************************************************
# duplicated: 87863
# **************************************************
# unique: ['Kolkata(Chinar Park)' 'Gandhinagar, Ahmedabad' 'Chennai' ...
#  'Bengaluru(Hennur +2)' 'Ahmedabad(Sindhu Bhavan Road +1)'
#  'Jammu(Nanak Nagar)']

# %%
# check Companyid
# check missing value
print("missing value:",df['Companyid'].isna().sum())
print("-"*50)

# check duplicated
print("duplicated:",df['Companyid'].duplicated().sum())
print("-"*50)

# check data type
print("dtype:",df['Companyid'].dtype)
print("-"*50)

print(df['Companyid'].nunique())
print("-"*50)

# remove space
#print(df['Companyid'].str.strips())
# Out:
# missing value: 0
# --------------------------------------------------
# duplicated: 79601
# --------------------------------------------------
# dtype: int64
# --------------------------------------------------
# 18328
# --------------------------------------------------

# %%
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           NaN              NaN
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimumsalary  \
# 0                    Preferred candidate profile . .       200000.0
# ...

# %%
# check Reviewscount coljumns
# check missing value
print("missing value:",df['Reviewscount'].isna().sum())
print("-"*50)
# check datatype
print("data type:",df['Reviewscount'].dtype)
print("-"*50)

# fill missing value
df['Reviewscount']=df['Reviewscount'].fillna(0)
print("after fill missing value:",df['Reviewscount'])
print("-"*50)

# check duplicated
print("duplicated:",df['Reviewscount'].duplicated().sum())
# Out:
# missing value: 35252
# --------------------------------------------------
# data type: float64
# --------------------------------------------------
# after fill missing value: 0           0.0
# 1        5162.0
# 2        2892.0
# 3           0.0
# 4        2134.0
#           ...
# 97924     284.0
# 97925      13.0
# 97926    2134.0
# 97927       0.0
# 97928       4.0
# Name: Reviewscount, Length: 97929, dtype: float64
# --------------------------------------------------
# duplicated: 96553

# %%
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           0.0              NaN
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimumsalary  \
# 0                    Preferred candidate profile . .       200000.0
# ...

# %%
# check missing value
print("missing value:",df['Aggregaterating'].isna().sum())
print("-"*50)
# Out:
# missing value: 35252
# --------------------------------------------------

# %%
# check  Aggregaterating columns
# check datatype
print("dtype:",df['Aggregaterating'].dtype)
print("-"*50)


# check how percentage missing value have
print("Missing %:", df['Aggregaterating'].isna().mean() * 100)
print("-"*50)

# fill missing value with using median
df['Aggregaterating']=df['Aggregaterating'].fillna(df['Aggregaterating'].median())
print(df['Aggregaterating'])
# check duplicated
print("duplicated:",df['Aggregaterating'].duplicated().sum())
print("-"*50)

# after fill missing value check missing value
print("after fill missing value:",df['Aggregaterating'].isna().sum())
# Out:
# dtype: float64
# --------------------------------------------------
# Missing %: 35.99750839894209
# --------------------------------------------------
# 0        3.7
# 1        4.0
# 2        4.2
# 3        3.7
# 4        3.4
#         ...
# 97924    4.2
# 97925    2.6
# 97926    3.4
# 97927    3.7
# 97928    4.2
# Name: Aggregaterating, Length: 97929, dtype: float64
# duplicated: 97888
# --------------------------------------------------
# after fill missing value: 0

# %%
# check Jobdescription columns
print("missing value:",df['Jobdescription'].isna().sum())
print("="*50)

# check datatypes
print("dtype:",df['Jobdescription'].dtype)
print("-"*50)
# remove space 
df['Jobdescription'].str.strip()

# check unique value
print("unique:",df['Jobdescription'].unique())
print("_"*50)

# convert into title case
df['Jobdescription']=df['Jobdescription'].str.title()
df['Jobdescription']
# Out:
# missing value: 0
# ...
# dtype: object
# --------------------------------------------------
# unique: ['Preferred candidate profile . .'
#  'Ensure active Fire Protection System,such as Fire Hydrant system,Fire extinguishers,Fire Alarm smoke detector system,Sprinkler system keep in good condition'
#  'MBA Marketing (preferred Tier II or III B- School). <br><br>Experience <br><br> 12+ years exp in Digital Marketing with a focus on performance marketing/ content strategy / campaign management along with team handling experience<br><br>Mobility Experience / development of mobile sites / Apps'
#  ... 'Documentation as per GLP requirement'
#  'Job title-Customer Care Associate\nJob location-Chandigarh\nSalary-22-23in hand\n\nQualification-Graduated/Postgraduated\nRotational shifts\nFluent english\nCab facility\n\n\nCall at 6239334478'
# ...

# %%
import numpy as np

# Rename column
df = df.rename(columns={"Minimumsalary": "Minimum_salary"})

# Check missing values
print("Missing values:", df['Minimum_salary'].isna().sum())
print("*" * 50)

# Check zero values BEFORE filling anything
zero_count = (df['Minimum_salary'] == 0).sum()
zero_percentage = (df['Minimum_salary'] == 0).mean() * 100

print("Zero values:", zero_count)
print("Zero percentage:", zero_percentage)
print("*" * 50)

# If 0 means salary not disclosed/unavailable,
# convert 0 to NaN
df['Minimum_salary'] = df['Minimum_salary'].replace(0, np.nan)

# Check missing values after replacing 0
print("Missing after replacing 0:",
      df['Minimum_salary'].isna().sum())

print("Missing percentage:",
      df['Minimum_salary'].isna().mean() * 100)
# Out:
# Missing values: 571
# **************************************************
# Zero values: 64129
# Zero percentage: 65.48519846010885
# **************************************************
# Missing after replacing 0: 64700
# Missing percentage: 66.06827395357861

# %%
print("Missing values:", df['Minimum_salary'].isna().sum())
print("*" * 50)
df['Minimum_salary'] = df['Minimum_salary'].fillna(df['Minimum_salary'].median())
df['Minimum_salary']
# Out:
# Missing values: 64700
# **************************************************
# 0        200000.0
# 1        300000.0
# 2        300000.0
# 3         70000.0
# 4        800000.0
#            ...
# 97924     50000.0
# 97925    300000.0
# 97926    300000.0
# 97927     70000.0
# 97928    192000.0
# Name: Minimum_salary, Length: 97929, dtype: float64

# %%
print("Missing values:", df['Minimum_salary'].isna().sum())
# Out:
# Missing values: 0

# %%
df.head(80)
# check unique value
print("unique:", df['Minimum_salary'].unique()[:25])
# chenge data type
df['Minimum_salary']=df['Minimum_salary'].astype(int)
df['Minimum_salary']
# Out:
# unique: [ 200000.  300000.   70000.  800000.  350000.   50000.  600000.  450000.
#   475000. 1000000.  700000.  400000.  150000.  325000. 2000000.  900000.
#   375000.   80000.  250000.  144000.  500000.  100000.  550000. 3000000.
#  1400000.]
# 0        200000
# 1        300000
# 2        300000
# 3         70000
# 4        800000
#           ...
# 97924     50000
# 97925    300000
# 97926    300000
# 97927     70000
# 97928    192000
# Name: Minimum_salary, Length: 97929, dtype: int64

# %%
df.head(50)
# Out:
#                                                 Title         Jobid Currency  \
# 0                           Sr. HR Recruiter (NON IT)  270925008041      INR
# 1                             Fire And Safety Officer  270925007584      INR
# 2         Opening For Performance Marketing - Chennai  270925007492      INR
# 3                           Medical Billing Executive  270925007443      INR
# 4         Senior Group Product Manager -  CNS Therapy  270925007430      INR
# 5                                   Senior Accountant  270925007323      INR
# 6                              Maintenance Technician  270925007180      INR
# 7                          Officer/Engineer Technical  270925006659      INR
# 8                              Officer- Technical Lab  270925006525      INR
# 9                           Site Reliability Engineer  270925006315      INR
# 10                    Hiring For Voice & Chat Process  270925006180      INR
# ...

# %%
# check Maximumsalary columns
# rename name  columns name
df=df.rename(columns={"Maximumsalary":"Maximum_salary"})
df
# check missing value
print("missing value:",df['Maximum_salary'].isna().sum())
print("*"*50)
# check how many 0 value have this columns
zero_count=(df['Maximum_salary'] == 0).sum()
print("zero_count:",zero_count)
print("*"*50)

# check 0 peracentage 
zero_per=(df['Maximum_salary']==0).mean() * 100
print("zero_per:",zero_per)
print("*"*50)

# convert them into NaN value
df['Maximum_salary']=df['Maximum_salary'].replace(0,np.nan)
df['Maximum_salary']
# Out:
# missing value: 571
# **************************************************
# zero_count: 64121
# **************************************************
# zero_per: 65.47702927631242
# **************************************************
# 0         400000.0
# 1         500000.0
# 2              NaN
# 3         200000.0
# 4        1800000.0
#            ...
# 97924     200000.0
# 97925          NaN
# 97926          NaN
# 97927     200000.0
# 97928     336000.0
# Name: Maximum_salary, Length: 97929, dtype: float64

# %%
# after covert nan check missing value
print("mussing value:",df['Maximum_salary'].isna().sum())
print("-"*50)
# Out:
# mussing value: 64692
# --------------------------------------------------

# %%
# fill then into  median
df['Maximum_salary']=df['Maximum_salary'].fillna(df['Maximum_salary'].median())
print("missing value:",df['Maximum_salary'])
print("-"*50)
print("mussing value:",df['Maximum_salary'].isna().sum())
print("-"*50)

# convert datatype float to  int
df['Maximum_salary']=df['Maximum_salary'].astype(int)
print("astype:",df['Maximum_salary'])
# Out:
# missing value: 0         400000.0
# 1         500000.0
# 2         550000.0
# 3         200000.0
# 4        1800000.0
#            ...
# 97924     200000.0
# 97925     550000.0
# 97926     550000.0
# 97927     200000.0
# 97928     336000.0
# Name: Maximum_salary, Length: 97929, dtype: float64
# --------------------------------------------------
# mussing value: 0
# --------------------------------------------------
# astype: 0         400000
# 1         500000
# 2         550000
# 3         200000
# 4        1800000
#           ...
# 97924     200000
# 97925     550000
# 97926     550000
# 97927     200000
# 97928     336000
# Name: Maximum_salary, Length: 97929, dtype: int64

# %%
# check Minimumexperience columns
# check data type
print("data type:",df['Minimumexperience'].dtype)
print("-"*50)

# check missing value
print("missing value:",df['Minimumexperience'].isna().sum())
print("-"*50)

# fill missing value using median
df['Minimumexperience']=df['Minimumexperience'].fillna(df['Minimumexperience'].median())
print(df['Minimumexperience'])
# Out:
# data type: float64
# --------------------------------------------------
# missing value: 571
# --------------------------------------------------
# 0         2.0
# 1         6.0
# 2        12.0
# 3         0.0
# 4         5.0
#          ...
# 97924     2.0
# 97925     1.0
# 97926     4.0
# 97927     0.0
# 97928     0.0
# Name: Minimumexperience, Length: 97929, dtype: float64

# %%
print("missing value:",df['Minimumexperience'].isna().sum())
print("-"*50)
# Out:
# missing value: 0
# --------------------------------------------------

# %%
# rename columns name
df = df.rename(columns={"Minimumexperience": "Minimum_experience"})
df.head(2)
# Out:
#                        Title         Jobid Currency Jobuploaded  \
# 0  Sr. HR Recruiter (NON IT)  270925008041      INR  6 Days Ago
# 1    Fire And Safety Officer  270925007584      INR  6 Days Ago
#
#                                          Companyname  \
# 0                                              Orion
# 1  Apollo Hospitals International Limited, Ahmedabad
#
#                                        Tagsandskills Experience       Salary  \
# 0  Communication,Manpower,Staffing,Convincing Pow...    2-4 Yrs  2-4 Lacs PA
# 1  Safety Officer Activities,Fire Protection,Fire...   6-11 Yrs  3-5 Lacs PA
#
#                  Location  Companyid  Reviewscount  Aggregaterating  \
# 0    Kolkata(Chinar Park)     645563           0.0              3.7
# 1  Gandhinagar, Ahmedabad      14072        5162.0              4.0
#
#                                       Jobdescription  Minimum_salary  \
# 0                    Preferred Candidate Profile . .          200000
# ...

# %%
# check Maximumexperience columns
# rename columns
df=df.rename(columns={"Maximumexperience":"Maximum_experience"})
df
# check missing value
print("missing value:",df['Maximum_experience'].isna().sum())
print("-"*50)
# Out:
# missing value: 571
# --------------------------------------------------

# %%
# fill missing value using meadian
df['Maximum_experience']=df['Maximum_experience'].fillna(df['Maximum_experience'].median())
print("missing value:",df['Maximum_experience'])
# Out:
# missing value: 0         4.0
# 1        11.0
# 2        18.0
# 3         3.0
# 4        10.0
#          ...
# 97924     5.0
# 97925     2.0
# 97926     9.0
# 97927     3.0
# 97928     3.0
# Name: Maximum_experience, Length: 97929, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97929 entries, 0 to 97928
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               97929 non-null  object
#  1   Jobid               97929 non-null  int64
#  2   Currency            97929 non-null  object
#  3   Jobuploaded         97929 non-null  object
#  4   Companyname         97929 non-null  object
#  5   Tagsandskills       97929 non-null  object
#  6   Experience          97929 non-null  object
#  7   Salary              97929 non-null  object
#  8   Location            97929 non-null  object
#  9   Companyid           97929 non-null  int64
#  10  Reviewscount        97929 non-null  float64
#  11  Aggregaterating     97929 non-null  float64
#  12  Jobdescription      97929 non-null  object
#  13  Minimum_salary      97929 non-null  int64
#  14  Maximum_salary      97929 non-null  int64
# ...

# %%
# save data set
df.to_csv('indian_job_market_clean_data.csv', index=False)
